# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

headers = {
    'authority': 'www.leeds.gov.uk',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'upgrade-insecure-requests': '1',
    'origin': 'https://www.leeds.gov.uk',
    'content-type': 'application/x-www-form-urlencoded',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.leeds.gov.uk/residents/bins-and-recycling/check-your-bin-day',
    'accept-language': 'en-US,en;q=0.9,en-GB;q=0.8',
    'cookie': 'visid_incap_2048550=7e7cFK+xQauOWWDiWO3uemBkImIAAAAAQUIPAAAAAADFKLfevW6TU6A4h6OFDgYM; incap_ses_1319_2048550=InbcEXla1RyAWPTo8gdOEmBkImIAAAAALDxorjVCWSYu5GvZL4wsiA==; WSS_FullScreenMode=false; SearchSession=3378e4b6%2D76c6%2D4a71%2D99b3%2Ddc98acd0f5c1',
}

data = {
  '_wpcmWpid': '',
  'wpcmVal': '',
  'MSOWebPartPage_PostbackSource': '',
  'MSOTlPn_SelectedWpId': '',
  'MSOTlPn_View': '0',
  'MSOTlPn_ShowSettings': 'False',
  'MSOGallery_SelectedLibrary': '',
  'MSOGallery_FilterString': '',
  'MSOTlPn_Button': 'none',
  '__EVENTTARGET': 'ctl00$ctl48$g_eea1a8ba_4306_488e_96f2_97f22038e29f$ctl00$ddlAddressList',
  '__EVENTARGUMENT': '',
  '__REQUESTDIGEST': '0x8825035918BD1CCA7917CA58A5622ECF8662B586D34D66FE1B47E01CAF45B92FC32B3E1FB970B2251BB46D46DFCE4F27E72AAB8650619351F8BF9F13D9FFD277,04 Mar 2022 19:24:16 -0000',
  'MSOSPWebPartManager_DisplayModeName': 'Browse',
  'MSOSPWebPartManager_ExitingDesignMode': 'false',
  'MSOWebPartPage_Shared': '',
  'MSOLayout_LayoutChanges': '',
  'MSOLayout_InDesignMode': '',
  '_wpSelected': '',
  '_wzSelected': '',
  'MSOSPWebPartManager_OldDisplayModeName': 'Browse',
  'MSOSPWebPartManager_StartWebPartEditingName': 'false',
  'MSOSPWebPartManager_EndWebPartEditing': 'false',
  '__LASTFOCUS': '',
  '__VIEWSTATE': '...',
  '__VIEWSTATEGENERATOR': 'BAB98CB3',
  '__EVENTVALIDATION': '...',
  'ctl00$ctl48$g_eea1a8ba_4306_488e_96f2_97f22038e29f$ctl00$txtPostCode': 'LS15 8fh',
  'ctl00$ctl48$g_eea1a8ba_4306_488e_96f2_97f22038e29f$ctl00$ddlAddressList': '72727132'
}

response = requests.post('https://www.leeds.gov.uk/residents/bins-and-recycling/check-your-bin-day', headers=headers, data=data)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html >\n<!--[if IE]><![endif]-->\n<!--[if lt IE 7 ]> <html lang="en" class="ie6">    <![endif]-->\n<!--[if IE 7 ]>    <html lang="en" class="ie7">    <![endif]-->\n<!--[if IE 8 ]>    <html lang="en" class="ie8">    <![endif]-->\n<!--[if IE 9 ]>    <html lang="en" class="ie9">    <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html dir="ltr" lang="en">\n <!--<![endif]-->\n <head>\n  <!-- Meta data -->\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="Microsoft SharePoint" name="GENERATOR"/>\n  <meta content="0" http-equiv="Expires"/>\n  <!-- Favicon -->\n  <link href="/_catalogs/masterpage/public/images/apple-touch-icon.png?1.1.66" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="/_catalogs/masterpage/public/images/favicon-32x32.png?1.1.66" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/_catalogs/masterpage/public/images/favicon-16x16.png?1.1.66" rel="icon" sizes="16x16" type="image/png"/>\n  <link href="/_catalogs/masterpage/public/images/favicon.ico?1.1.66" rel="shortcut icon"/>\n  <link href="/_catalogs/masterpage/public/images/manifest.json?1.1.66" rel="manifest"/>\n  <link color="#5bbad5" href="/_catalogs/masterpage/public/images/safari-pinned-tab.svg?1.1.66" rel="mask-icon"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <!-- Bootstrap CSS -->\n  <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.1/css/bootstrap.min.css" ms-design-css-conversion="no" rel="stylesheet" type="text/css"/>\n  <script src="https://cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js">\n  </script>\n  <!-- Custom font using Typekit -->\n  <script src="https://use.typekit.net/pws7qio.js">\n  </script>\n  <script>\n   try{Typekit.load({ async: true });}catch(e){}\n  </script>\n  <!-- Open Graph Data -->\n  <meta content="https://www.leeds.gov.uk/_catalogs/masterpage/public/images/leeds-city-council-logo.jpg" property="og:image"/>\n  <meta content="1080" property="og:image:width"/>\n  <meta content="1080" property="og:image:height"/>\n  <!-- SharePoint scripts -->\n  <link href="/_layouts/15/1033/styles/Themable/corev15.css?rev=WBDzE8Kp2NMrldHsGGXlEQ%3D%3D" rel="stylesheet" type="text/css"/>\n  <link href="/Style%20Library/en-US/Themable/Core%20Styles/pagelayouts15.css" rel="stylesheet" type="text/css"/>\n  <link href="/_layouts/15/1033/styles/Themable/searchv15.css?rev=qarmmE3eURu3ZS2Wsbpf2w%3D%3D" rel="stylesheet" type="text/css"/>\n  <link href="/Style%20Library/en-US/Themable/Core%20Styles/controls15.css" rel="stylesheet" type="text/css"/>\n  <!-- Page title -->\n  <title>\n   Check your bin day\n  </title>\n  <!-- SharePoint scripts -->\n  <script src="/_layouts/15/init.js?rev=AS%2Bv0UYCkcLYkV95cqJXGA%3D%3D" type="text/javascript">\n  </script>\n  <script src="/ScriptResource.axd?d=KGBziKg9s9_cDqnIw2YNXYRGqwgsdD2giOwMId7EPA1HTJVI2I89HvLytu05CQd-lLEa-lmZhfar9K3SiLQ8Eu-0lWsbdoUKWklnwJm5R9zkFOBpPRELnXKnXtY0l8Ahk98lkN4b5WfFPlF56jiGjKGKQyrzTLGXNzQeTPAOAG-wBntQxzchsJDDBYAJpYwX0&amp;t=ffffffffd202a464" type="text/javascript">\n  </script>\n  <script src="/_layouts/15/blank.js?rev=ZaOXZEobVwykPO9g8hq%2F8A%3D%3D" type="text/javascript">\n  </script>\n  <script src="/ScriptResource.axd?d=SoL2S3y5DUhYiBNjk9LI5Cb8VE9D0OKMyUD7Q5rx0vW2tqu8cf4fbc1Jg1A1yKJSYElVe_83uyxUJc30XoPzfWWcyUqf_zVL0gYhJD7eKw2vBTQSwD2iFB6O6vb9UQfun8-LHhEWe59o7UhuozLpFT39aCsCVBZj_GPV2fwkcwBMSrk-c9v_Foh8C5faPlNI0&amp;t=ffffffffd202a464" type="text/javascript">\n  </script>\n  <script src="/_layouts/15/sp.init.js?rev=jvJC3Kl5gbORaLtf7kxULQ%3D%3D" type="text/javascript">\n  </script>\n  <script src="/_layouts/15/clientrenderer.js?rev=PWwV4FATEiOxN90BeB5Hzw%3D%3D" type="text/javascript">\n  </script>\n  <script src="/_layouts/15/ScriptResx.ashx?culture=en%2Dus&amp;name=Srch%2EResources&amp;rev=fPbk%2B7qByTbyuNVTMptzRw%3D%3D" type="text/javascript">\n  </script>\n  <script src="/_layouts/15/search.clientcontrols.js?r ...

# %%
data = soup.find('div', attrs={'id': lambda e: e.endswith('BinResultsDetails') if e else False})

# %%
result = data.find_all('div', attrs={'class': 'selectedContainer'})

# %%
bin_info = {}
for i in result:
    days = []
    for j in i.find_all('li'):
        txt = str(j.contents[0])
        txt = txt[txt.find(' ')+1:]
        days.append(datetime.strptime(txt, r'%d %b %Y').date())
    bin_info[i.h3.contents[1]] = days

# %%
new_dict = {}
for key, value in bin_info.items():
    for i in value:
        if i in new_dict:
            new_dict[i].append(key)
        else:
            new_dict[i] = [key]

# %%
min(new_dict.items(), key=lambda x: x[1])
# Out:
# (datetime.date(2022, 3, 12), ['Black bin collection days.'])

# %%
d = bin_info
min(d.items(), key=lambda x: x[0])
# Out:
# ('Black bin collection days.',
#  [datetime.date(2022, 3, 12),
#   datetime.date(2022, 3, 26),
#   datetime.date(2022, 4, 9),
#   datetime.date(2022, 4, 23),
#   datetime.date(2022, 5, 7),
#   datetime.date(2022, 5, 21),
#   datetime.date(2022, 6, 4),
#   datetime.date(2022, 6, 18),
#   datetime.date(2022, 7, 2),
#   datetime.date(2022, 7, 16),
#   datetime.date(2022, 7, 30),
#   datetime.date(2022, 8, 13)])
